# %%
import pandas as pd
import regex as re
from tqdm.notebook import tqdm
import os

site = 'http://www.lada-vesta.net/'
folder_names = [
    ['0', 'Отзывы', 'f=25', 'LADA VESTA'],
    ['1', 'Двигатель', 'f=14', 'LADA VESTA'],
    ['2', 'Трансмиссия', 'f=15', 'LADA VESTA'],
    ['3', 'Ходовая', 'f=16', 'LADA VESTA'],
    ['4', 'Колеса', '', 'LADA VESTA'],
    ['5', 'Электрооборудование', 'f=17', 'LADA VESTA'],
    ['6', 'Мультимедиа', '', 'LADA VESTA'],
    ['7', 'Кузов', 'f=18', 'LADA VESTA'],
    ['8', 'Жидкости', 'f=19', 'LADA VESTA'],
    ['9', 'Сервис', 'f=42', 'LADA VESTA'],
    ['10', 'Эксплуатация', 'f=23', 'LADA VESTA'],
    ['11', 'Тюнинг', 'f=24', 'LADA VESTA']
]

# %%
folder_name = folder_names[3]
f_name = folder_name[3] + '/' + folder_name[3] + '_' + folder_name[0] + '_' + folder_name[1] + '.csv'
f_name
# Out:
# 'LADA VESTA/LADA VESTA_3_Ходовая.csv'

# %%
mess = pd.read_csv('./' + f_name, quotechar="'")
mess
# Out:
#        Code   Folder                   Theme        Date    Time       Author  \
# 0         3  Ходовая  FAQ Ходовая и подвеска  29.09.2016   18:43       Oleg08
# 1         3  Ходовая  FAQ Ходовая и подвеска  13.10.2016   23:26     bokareff
# 2         3  Ходовая  FAQ Ходовая и подвеска  17.10.2016   16:48     bokareff
# 3         3  Ходовая  FAQ Ходовая и подвеска  08.06.2019   22:23        chand
# 4         3  Ходовая  FAQ Ходовая и подвеска  09.06.2019   08:13       katran
# ...     ...      ...                     ...         ...     ...          ...
# 15840     3  Ходовая                 Докатка  06.05.2016   07:10      Ladavod
# 15841     3  Ходовая                 Докатка  06.05.2016   11:16       becool
# 15842     3  Ходовая                 Докатка  06.05.2016   19:09       Ризван
# 15843     3  Ходовая                 Докатка  06.05.2016   20:30  авторевизор
# 15844     3  Ходовая                 Докатка  07.05.2016   13:14          БВМ
#
# ...

# %%
f = (mess['Theme'].str.count('Выбор.+резины') > 0) \
| (mess['Theme'].str.count('Подбор.+дисков') > 0) \
| (mess['Theme'].str.count('Колёса') > 0)

# %%
mess.iloc[f,0] = 4
mess.iloc[f,1] = 'Колеса'

# %%
mess[f]
# Out:
#        Code  Folder                        Theme        Date    Time  \
# 1683      4  Колеса          Выбор летней резины  08.04.2016   13:14
# 1684      4  Колеса          Выбор летней резины  09.04.2016   12:35
# 1685      4  Колеса          Выбор летней резины  09.04.2016   12:55
# 1686      4  Колеса          Выбор летней резины  09.04.2016   14:11
# 1687      4  Колеса          Выбор летней резины  09.04.2016   14:28
# ...     ...     ...                          ...         ...     ...
# 19905     4  Колеса  Выбор зимней резины - Архив  12.10.2017   11:13
# 19906     4  Колеса  Выбор зимней резины - Архив  12.10.2017   11:53
# 19907     4  Колеса  Выбор зимней резины - Архив  12.10.2017   13:57
# 19908     4  Колеса  Выбор зимней резины - Архив  12.10.2017   16:03
# 19909     4  Колеса  Выбор зимней резины - Архив  12.10.2017   17:19
#
#              Author                                            Message
# ...

# %%
folder_name = folder_names[4]
f_name = folder_name[3] + '/' + folder_name[3] + '_' + folder_name[0] + '_' + folder_name[1] + '.csv'
f_name
# Out:
# 'LADA VESTA/LADA VESTA_4_Колеса.csv'

# %%
mess[f].to_csv(path_or_buf='./' + f_name, index=False, quotechar="'", escapechar='`')

# %%
updated = pd.read_csv('./' + f_name, quotechar="'")
updated
# Out:
#       Code  Folder                        Theme        Date    Time  \
# 0        4  Колеса          Выбор летней резины  08.04.2016   13:14
# 1        4  Колеса          Выбор летней резины  09.04.2016   12:35
# 2        4  Колеса          Выбор летней резины  09.04.2016   12:55
# 3        4  Колеса          Выбор летней резины  09.04.2016   14:11
# 4        4  Колеса          Выбор летней резины  09.04.2016   14:28
# ...    ...     ...                          ...         ...     ...
# 7114     4  Колеса  Выбор зимней резины - Архив  12.10.2017   11:13
# 7115     4  Колеса  Выбор зимней резины - Архив  12.10.2017   11:53
# 7116     4  Колеса  Выбор зимней резины - Архив  12.10.2017   13:57
# 7117     4  Колеса  Выбор зимней резины - Архив  12.10.2017   16:03
# 7118     4  Колеса  Выбор зимней резины - Архив  12.10.2017   17:19
#
#             Author                                            Message
# 0      Uncle Sasha   Начинают аквапланировать уже после 90 км/час....
# ...

# %%
folder_name = folder_names[3]
f_name = folder_name[3] + '/' + folder_name[3] + '_' + folder_name[0] + '_' + folder_name[1] + '.csv'
f_name
# Out:
# 'LADA VESTA/LADA VESTA_3_Ходовая.csv'

# %%
mess[-f]
# Out:
#        Code   Folder                   Theme        Date    Time       Author  \
# 0         3  Ходовая  FAQ Ходовая и подвеска  29.09.2016   18:43       Oleg08
# 1         3  Ходовая  FAQ Ходовая и подвеска  13.10.2016   23:26     bokareff
# 2         3  Ходовая  FAQ Ходовая и подвеска  17.10.2016   16:48     bokareff
# 3         3  Ходовая  FAQ Ходовая и подвеска  08.06.2019   22:23        chand
# 4         3  Ходовая  FAQ Ходовая и подвеска  09.06.2019   08:13       katran
# ...     ...      ...                     ...         ...     ...          ...
# 22959     3  Ходовая                 Докатка  06.05.2016   07:10      Ladavod
# 22960     3  Ходовая                 Докатка  06.05.2016   11:16       becool
# 22961     3  Ходовая                 Докатка  06.05.2016   19:09       Ризван
# 22962     3  Ходовая                 Докатка  06.05.2016   20:30  авторевизор
# 22963     3  Ходовая                 Докатка  07.05.2016   13:14          БВМ
#
# ...

# %%
mess[-f].to_csv(path_or_buf='./' + f_name, index=False, quotechar="'", escapechar='`')

# %%
folder_name = folder_names[5]
f_name = folder_name[3] + '/' + folder_name[3] + '_' + folder_name[0] + '_' + folder_name[1] + '.csv'
f_name
# Out:
# 'LADA VESTA/LADA VESTA_5_Электрооборудование.csv'

# %%
mess = pd.read_csv('./' + f_name, quotechar="'")
mess
# Out:
#        Code               Folder    Theme        Date    Time       Author  \
# 0         5  Электрооборудование    Схемы  01.12.2015   01:31       Oleg08
# 1         5  Электрооборудование    Схемы  01.12.2015   14:08        rvs63
# 2         5  Электрооборудование    Схемы  02.12.2015   16:00        rvs63
# 3         5  Электрооборудование    Схемы  30.12.2015   13:06  Afterburner
# 4         5  Электрооборудование    Схемы  30.12.2015   16:45       Oleg08
# ...     ...                  ...      ...         ...     ...          ...
# 22470     5  Электрооборудование  Сигналы  22.10.2015   13:54       Martin
# 22471     5  Электрооборудование  Сигналы  22.10.2015   13:58  авторевизор
# 22472     5  Электрооборудование  Сигналы  22.10.2015   14:13        rvs63
# 22473     5  Электрооборудование  Сигналы  24.10.2015   23:04    Ваня Брос
# 22474     5  Электрооборудование  Сигналы  28.01.2016   14:32       Martin
#
#                                                  Message
# ...

# %%
mess.Theme.unique()
# Out:
# array(['Схемы', 'FAQ Электрооборудование',
#        'Аккумулятор (выбор, эксплуатация, зарядка) - 4',
#        'Головной свет, противотуманки и пр. - 3',
#        'Обогревы лобового стекла и пр. - 2',
#        'нет звука в задней левой двери',
#        'Магнитола Vesta (без телевизора)', 'Панель приборов',
#        'Сломалась регулировка зеркал', 'Датчик дождя',
#        'Эра-глонасс в Vesta', 'проблема с запуском ДВС',
#        'Из Весты в Теслу', 'Камера ЗВ', 'простейший климат контроль',
#        'Расход энергии в режиме ожидания (ток)', 'CAN шина, ELM327 и пр.',
#        'Работа стеклоподъемников', 'Врёт спидометр на веста СВ Кросс',
#        'Круиз', 'Добавляем штатные кнопки на панель.',
#        'Штатная антенна ( радио ) как, где?',
#        'Климат-контроль, блок управления отопителем и кондиционером и пр.',
#        'ACC включается только после прогрева',
#        'Блок кузовной электроники EMM 231A02188R',
#        'Лампы светодиодные в весте. Опыт', 'Датчик света',
# ...

# %%
f = (mess['Theme'].str.count('[Мм]агнитол') > 0) \
    | (mess['Theme'].str.count('радио') > 0) \
    | (mess['Theme'].str.count('[Кк]амер') > 0) \
    | (mess['Theme'].str.count('[Мм]ультимед') > 0) \
    | (mess['Theme'].str.count('блютуз') > 0) \
    | (mess['Theme'].str.count('экран') > 0)

# %%
mess[f]
# Out:
#        Code       Folder                             Theme        Date  \
# 1636      6  Мультимедиа  Магнитола Vesta (без телевизора)  18.05.2020
# 1637      6  Мультимедиа  Магнитола Vesta (без телевизора)  19.05.2020
# 1638      6  Мультимедиа  Магнитола Vesta (без телевизора)  24.07.2020
# 1639      6  Мультимедиа  Магнитола Vesta (без телевизора)  24.07.2020
# 1640      6  Мультимедиа  Магнитола Vesta (без телевизора)  24.07.2020
# ...     ...          ...                               ...         ...
# 28576     6  Мультимедиа  Ток при зарядке от USB магнитолы  30.01.2016
# 28577     6  Мультимедиа  Ток при зарядке от USB магнитолы  30.01.2016
# 28578     6  Мультимедиа  Ток при зарядке от USB магнитолы  04.02.2016
# 28579     6  Мультимедиа  Ток при зарядке от USB магнитолы  04.02.2016
# 28580     6  Мультимедиа  Ток при зарядке от USB магнитолы  07.03.2016
#
#          Time     Author                                            Message
# ...

# %%
mess.iloc[f,0] = 6
mess.iloc[f,1] = 'Мультимедиа'

# %%
folder_name = folder_names[6]
f_name = folder_name[3] + '/' + folder_name[3] + '_' + folder_name[0] + '_' + folder_name[1] + '.csv'
f_name
# Out:
# 'LADA VESTA/LADA VESTA_6_Мультимедиа.csv'

# %%
mess[f].to_csv(path_or_buf='./' + f_name, index=False, quotechar="'", escapechar='`')

# %%
updated = pd.read_csv('./' + f_name, quotechar="'")
updated
# Out:
#       Code       Folder                             Theme        Date    Time  \
# 0        6  Мультимедиа  Магнитола Vesta (без телевизора)  18.05.2020   22:40
# 1        6  Мультимедиа  Магнитола Vesta (без телевизора)  19.05.2020   09:16
# 2        6  Мультимедиа  Магнитола Vesta (без телевизора)  24.07.2020   12:32
# 3        6  Мультимедиа  Магнитола Vesta (без телевизора)  24.07.2020   13:10
# 4        6  Мультимедиа  Магнитола Vesta (без телевизора)  24.07.2020   13:18
# ...    ...          ...                               ...         ...     ...
# 6199     6  Мультимедиа  Ток при зарядке от USB магнитолы  30.01.2016   20:29
# 6200     6  Мультимедиа  Ток при зарядке от USB магнитолы  30.01.2016   22:39
# 6201     6  Мультимедиа  Ток при зарядке от USB магнитолы  04.02.2016   10:18
# 6202     6  Мультимедиа  Ток при зарядке от USB магнитолы  04.02.2016   15:01
# 6203     6  Мультимедиа  Ток при зарядке от USB магнитолы  07.03.2016   11:47
#
# ...

# %%
folder_name = folder_names[5]
f_name = folder_name[3] + '/' + folder_name[3] + '_' + folder_name[0] + '_' + folder_name[1] + '.csv'
f_name
# Out:
# 'LADA VESTA/LADA VESTA_5_Электрооборудование.csv'

# %%
mess[-f].to_csv(path_or_buf='./' + f_name, index=False, quotechar="'", escapechar='`')

# %%
mess = pd.read_csv('./' + f_name, quotechar="'")
mess
# Out:
#        Code               Folder    Theme        Date    Time       Author  \
# 0         5  Электрооборудование    Схемы  01.12.2015   01:31       Oleg08
# 1         5  Электрооборудование    Схемы  01.12.2015   14:08        rvs63
# 2         5  Электрооборудование    Схемы  02.12.2015   16:00        rvs63
# 3         5  Электрооборудование    Схемы  30.12.2015   13:06  Afterburner
# 4         5  Электрооборудование    Схемы  30.12.2015   16:45       Oleg08
# ...     ...                  ...      ...         ...     ...          ...
# 22470     5  Электрооборудование  Сигналы  22.10.2015   13:54       Martin
# 22471     5  Электрооборудование  Сигналы  22.10.2015   13:58  авторевизор
# 22472     5  Электрооборудование  Сигналы  22.10.2015   14:13        rvs63
# 22473     5  Электрооборудование  Сигналы  24.10.2015   23:04    Ваня Брос
# 22474     5  Электрооборудование  Сигналы  28.01.2016   14:32       Martin
#
#                                                  Message
# ...
