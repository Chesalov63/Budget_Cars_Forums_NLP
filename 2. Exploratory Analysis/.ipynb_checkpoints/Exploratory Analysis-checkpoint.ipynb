# %%
import pandas as pd
from tqdm.notebook import tqdm

# %%
VestaExamples = pd.read_csv('../1. Data Extraction/LADA VESTA/LADA VESTA_3_Ходовая.csv', quotechar="'")
VestaExamples
# Out:
#        Code   Folder                   Theme        Date    Time       Author  \
# 0         3  Ходовая  FAQ Ходовая и подвеска  29.09.2016   18:43       Oleg08
# 1         3  Ходовая  FAQ Ходовая и подвеска  13.10.2016   23:26     bokareff
# 2         3  Ходовая  FAQ Ходовая и подвеска  17.10.2016   16:48     bokareff
# 3         3  Ходовая  FAQ Ходовая и подвеска  08.06.2019   22:23        chand
# 4         3  Ходовая  FAQ Ходовая и подвеска  09.06.2019   08:13       katran
# ...     ...      ...                     ...         ...     ...          ...
# 15840     3  Ходовая                 Докатка  06.05.2016   07:10      Ladavod
# 15841     3  Ходовая                 Докатка  06.05.2016   11:16       becool
# 15842     3  Ходовая                 Докатка  06.05.2016   19:09       Ризван
# 15843     3  Ходовая                 Докатка  06.05.2016   20:30  авторевизор
# 15844     3  Ходовая                 Докатка  07.05.2016   13:14          БВМ
#
#                                                  Message
# 0       ПОЛИУРЕТАН 2501591 - Втулка стабилизатора пер...
# 1
# 2       Документация В одном архиве: https://cloud.ma...
# 3                          Развал у Весты выставляется?
# 4                                  Нет не выставляется.
# ...                                                  ...
# 15840   У нас колеса реношные стоят, в ту сторону и с...
# 15841   Так вроде мелькала инфа, что с недавних пор н...
# 15842   Да это наверное обычный штампованный диск, та...
# 15843                             Вот на Драйве ставили
# 15844   У меня на ноуте такая же разболтовка, докатка...
#
# [15845 rows x 7 columns]

# %%
RioExamples = pd.read_csv('../1. Data Extraction/KIA RIO/KIA RIO_3_Ходовая.csv', quotechar="'")
RioExamples
# Out:
#                                                         Code  \
# 3 Ходовая  Дребезг (подобно банке с болтами) спереди спра...
#   Ходовая  Дребезг (подобно банке с болтами) спереди спра...
#   Ходовая  Дребезг (подобно банке с болтами) спереди спра...
#   Ходовая  Дребезг (подобно банке с болтами) спереди спра...
#   Ходовая  Дребезг (подобно банке с болтами) спереди спра...
# ...                                                      ...
#   Ходовая                                      Щелчки в руле
#   Ходовая                                      Щелчки в руле
#   Ходовая                                      Щелчки в руле
#   Ходовая                                      Щелчки в руле
#   Ходовая                                      Щелчки в руле
#
#                      Folder    Theme  \
# 3 Ходовая  07.11.2018 18:11     King
#   Ходовая  07.11.2018 18:14      ссе
#   Ходовая  07.11.2018 18:22     King
#   Ходовая  07.11.2018 18:22      Мав
#   Ходовая  07.11.2018 18:26      ссе
# ...                     ...      ...
#   Ходовая  10.01.2018 20:51    аdmin
#   Ходовая  10.01.2018 21:05  kolvich
#   Ходовая  10.01.2018 23:54  Anton90
#   Ходовая  10.01.2018 23:57  Anton90
#   Ходовая  11.01.2018 01:54  Anton90
#
#                                                      Message
# 3 Ходовая   Приветствую ! Создал новую тему, так как проб...
#   Ходовая   Как версия: ежели стоит защита, то поищите по...
#   Ходовая   В том то и проблема, что все эти элементарные...
#   Ходовая   @King, думаю вариант не Ваш, но все же скажу....
#   Ходовая   Ну тогда ищите. Но не так, как в том фильме: ...
# ...                                                      ...
#   Ходовая   Видео выложите на ютуб, сделайте публичным и ...
#   Ходовая   Посмотрите нет ли наклейки между рулем и кожу...
#   Ходовая   Вот видео Часть 1: [youtu.be/dyP8VIVAcFQ недо...
#   Ходовая                                    Видео часть 2:
#   Ходовая   kolvich, хорошо, обязательно посмотрю, спасиб...
#
# [1450 rows x 4 columns]

# %%
import nltk
from nltk.corpus import stopwords
from pymystem3 import Mystem
from string import punctuation

mystem = Mystem()
russian_stopwords = stopwords.words("russian")

def preprocess_text(text):
    tokens = mystem.lemmatize(text.lower())
    tokens = [token for token in tokens if token not in russian_stopwords \
         and token != " " \
         and token.strip() not in punctuation]
    
    text = " ".join(tokens)
    
    return text

#применение:
preprocess_text(RioExamples.iloc[0].Message)
# Out:
#  Приветствую ! Создал новую тему, так как проблема очень напрягает и в моём городке не у меня одного, но что это такое понять никто не может. Очень напрягает отчётливо слышный посторонний звук спереди справа при проезде неровностей (залатанный асфальт, при съезде с лежачего полицейского...), звук похож больше на дребезг что-ли, но не стук, будто металлическую банку с болтами где-то запрятали ! И точно не пойму откуда звук-то ли от подвески или от каких-либо наружных элементов, то ли из под капота...будто что то подкидывает на неровностях и возвращает обратно (банку с болтами) ! Начало прослушиваться отчётливо это с первой тысячи км !
# 'приветствовать создавать новый тема проблема очень напрягать городок это понимать никто мочь очень напрягать отчетливо слышный посторонний звук спереди справа проезд неровность залатать асфальт съезд лежачий полицейский ... ),  звук похожий дребезг стук металлический банка болт где-то запрятывать точно понимать откуда звук подвеска какой-либо наружный элемент капот ... подкидывать неровность возвращать обратно банка болт начинать прослушиваться отчетливо это первый тысяча км'

# %%
from tqdm.notebook import tqdm
def tokenize_corpus(texts, tokenizer=preprocess_text, **tokenizer_kwargs):
    return [preprocess_text(text, **tokenizer_kwargs) for text in tqdm(texts)]

# %%
messages_tokenized = tokenize_corpus(RioExamples.Message)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1450.0), HTML(value='')))
#  Приветствую ! Создал новую тему, так как проблема очень напрягает и в моём городке не у меня одного, но что это такое понять никто не может. Очень напрягает отчётливо слышный посторонний звук спереди справа при проезде неровностей (залатанный асфальт, при съезде с лежачего полицейского...), звук похож больше на дребезг что-ли, но не стук, будто металлическую банку с болтами где-то запрятали ! И точно не пойму откуда звук-то ли от подвески или от каких-либо наружных элементов, то ли из под капота...будто что то подкидывает на неровностях и возвращает обратно (банку с болтами) ! Начало прослушиваться отчётливо это с первой тысячи км !
#  Как версия: ежели стоит защита, то поищите под ней камешек какой, или, скорее всего гаечку-болтик. К стати, из моей неравной борьбы со стуками-грюками: откройте капот и потрогайте "кочергу"(упор капота). Если болтается с этим самым звуком, то намотайте изоленту на него или поправьте накладку(типа трубочки, ну не знаю как правильно называется!) на нём в районе крепления упора к капоту. Успеха и отпишитесь
#  Подтверждаю тоже как банка с болтами справа дребезг при проезде неровностей, не всех, чаще возникает при проезде резких, острых,стыков , например на мосту т.п. кто-нибудь нашел причину?
#  Попробуйте постучать по бачку для омывайки - он с чем то соприкасается и издает такой звук
#  У меня такая же проблема сзади,все перебрал,2 сервиса обьехал,в обеих сделали вывод-направляющие суппортов менять,грохочет как банка с болтами,буду менять.хотя руками дергаешь,ничего не болтается!!пробег 86000 все родное стоит еще.киа рио 3.2013 год.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-0de7003cdcd2> in <module>
# ----> 1 messages_tokenized = tokenize_corpus(RioExamples.Message)
#
# <ipython-input-28-10822bb79c8d> in tokenize_corpus(texts, tokenizer, **tokenizer_kwargs)
#       1 from tqdm.notebook import tqdm
#       2 def tokenize_corpus(texts, tokenizer=preprocess_text, **tokenizer_kwargs):
# ----> 3     return [preprocess_text(text, **tokenizer_kwargs) for text in tqdm(texts)]
#
# <ipython-input-28-10822bb79c8d> in <listcomp>(.0)
#       1 from tqdm.notebook import tqdm
#       2 def tokenize_corpus(texts, tokenizer=preprocess_text, **tokenizer_kwargs):
# ----> 3     return [preprocess_text(text, **tokenizer_kwargs) for text in tqdm(texts)]
#
# <ipython-input-27-5501258bfb89> in preprocess_text(text)
#       9 def preprocess_text(text):
#      10     print(text)
# ---> 11     tokens = mystem.lemmatize(text.lower())
#      12     tokens = [token for token in tokens if token not in russian_stopwords \
#      13          and token != " " \
#
# D:\Anaconda3\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# D:\Anaconda3\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# D:\Anaconda3\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     311             self._procin.write(_NL)
#     312
# --> 313             out, _ = self._proc.communicate()
#     314             self._proc = None
#     315             try:
#
# D:\Anaconda3\lib\subprocess.py in communicate(self, input, timeout)
#    1022
#    1023             try:
# -> 1024                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1025             except KeyboardInterrupt:
#    1026                 # https://bugs.python.org/issue25942
#
# D:\Anaconda3\lib\subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1393             # calls communicate again.
#    1394             if self.stdout is not None:
# -> 1395                 self.stdout_thread.join(self._remaining_time(endtime))
#    1396                 if self.stdout_thread.is_alive():
#    1397                     raise TimeoutExpired(self.args, orig_timeout)
#
# D:\Anaconda3\lib\threading.py in join(self, timeout)
#    1009
#    1010         if timeout is None:
# -> 1011             self._wait_for_tstate_lock()
#    1012         else:
#    1013             # the behavior of a negative timeout isn't documented, but
#
# D:\Anaconda3\lib\threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1025         if lock is None:  # already determined that the C code is done
#    1026             assert self._is_stopped
# -> 1027         elif lock.acquire(block, timeout):
#    1028             lock.release()
#    1029             self._stop()
#
# KeyboardInterrupt:
