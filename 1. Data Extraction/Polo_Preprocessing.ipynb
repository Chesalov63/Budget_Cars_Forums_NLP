# %%
import pandas as pd
import regex as re
from tqdm.notebook import tqdm
import os

site = 'http://www.polosedan-club.com/'
folder_names = [
    ['0', 'Отзывы', 'Отзывы-владельцев-о-Поло-седан-polo-sedan.13', 'FW POLO'],
    ['1', 'Двигатель', 'Двигатель-и-его-системы.18', 'FW POLO'],
    ['2', 'Трансмиссия', 'Сцепление-и-коробка-передач.19', 'FW POLO'],
    ['3', 'Ходовая', 'Ходовая-и-подвеска.20', 'FW POLO'],
    ['4', 'Колеса', 'Шины-и-колесные-диски.32', 'FW POLO'],
    ['5', 'Электрооборудование', 'Электрооборудование.21', 'FW POLO'],
    ['6', 'Мультимедиа', 'Аудио-Видео-системы-автомобиля.43', 'FW POLO'],
    ['7', 'Кузов', 'Кузов-и-система-отопления.22', 'FW POLO'],
    ['8', 'Жидкости', 'Топливо-и-эксплуатационные-жидкости.23', 'FW POLO'],
    ['9', 'Сервис', 'Гарантийное-и-сервисное-обслуживание.16', 'FW POLO'],
    ['10', 'Эксплуатация', 'Общие-вопросы-эксплуатации.17', 'FW POLO']
]

# %%
folder_name = folder_names[3]
f_name = folder_name[3] + '/' + folder_name[3] + '_' + folder_name[0] + '_' + folder_name[1] + '.csv'
f_name
# Out:
# 'FW POLO/FW POLO_3_Ходовая.csv'

# %%
mess = pd.read_csv('./' + f_name, quotechar="'")
mess
# Out:
#        Code   Folder                                              Theme  \
# 0         3  Ходовая                               Стойки стабилизатора
# 1         3  Ходовая                               Стойки стабилизатора
# 2         3  Ходовая                               Стойки стабилизатора
# 3         3  Ходовая                               Стойки стабилизатора
# 4         3  Ходовая                               Стойки стабилизатора
# ...     ...      ...                                                ...
# 25450     3  Ходовая  Машина сама тормозит  после того как убираю но...
# 25451     3  Ходовая  Машина сама тормозит  после того как убираю но...
# 25452     3  Ходовая  Машина сама тормозит  после того как убираю но...
# 25453     3  Ходовая  Машина сама тормозит  после того как убираю но...
# 25454     3  Ходовая  Машина сама тормозит  после того как убираю но...
#
#               Date          Author  \
# 0      20 авг 2014          kudzho
# ...

# %%
f = (mess['Theme'].str.count('Летняя резина') > 0) \
| (mess['Theme'].str.count('на колёса') > 0) \
| (mess['Theme'].str.count('смены резины') > 0) \
| (mess['Theme'].str.count('на диски') > 0)

# %%
mess[f].Theme.value_counts()
# Out:
# Series([], Name: Theme, dtype: int64)

# %%
## Темы про шины и диски относим в каталог "Колеса"
mess.iloc[f,0] = 4
mess.iloc[f,1] = 'Колеса'

# %%
mess[f]
# Out:
# Empty DataFrame
# Columns: [Code, Folder, Theme, Date, Author, Message]
# Index: []

# %%
folder_name = folder_names[4]
f_name = folder_name[3] + '/' + folder_name[3] + '_' + folder_name[0] + '_' + folder_name[1] + '.csv'
f_name
# Out:
# 'FW POLO/FW POLO_4_Колеса.csv'

# %%
## Создаем новый файл для колес
mess[f].to_csv(path_or_buf='./' + f_name, index=False, quotechar="'", escapechar='`')

# %%
updated = pd.read_csv('./' + f_name, quotechar="'")
updated
# Out:
#       Code  Folder                                             Theme  \
# 0        4  Колеса  ЦЕПИ на колёса для зимы. Резиновые или Железные?
# 1        4  Колеса  ЦЕПИ на колёса для зимы. Резиновые или Железные?
# 2        4  Колеса  ЦЕПИ на колёса для зимы. Резиновые или Железные?
# 3        4  Колеса  ЦЕПИ на колёса для зимы. Резиновые или Железные?
# 4        4  Колеса  ЦЕПИ на колёса для зимы. Резиновые или Железные?
# ...    ...     ...                                               ...
# 4467     4  Колеса   Вибрация на ходу из-за налипшего снега на диски
# 4468     4  Колеса   Вибрация на ходу из-за налипшего снега на диски
# 4469     4  Колеса   Вибрация на ходу из-за налипшего снега на диски
# 4470     4  Колеса   Вибрация на ходу из-за налипшего снега на диски
# 4471     4  Колеса   Вибрация на ходу из-за налипшего снега на диски
#
#              Date      Author  \
# 0      7 окт 2013  Hunter 4x4
# 1      7 окт 2013  Hunter 4x4
# 2      7 окт 2013     kosmich
# ...

# %%
folder_name = folder_names[3]
f_name = folder_name[3] + '/' + folder_name[3] + '_' + folder_name[0] + '_' + folder_name[1] + '.csv'
f_name
# Out:
# 'FW POLO/FW POLO_3_Ходовая.csv'

# %%
mess[-f]
# Out:
#        Code   Folder                                              Theme  \
# 0         3  Ходовая                               Стойки стабилизатора
# 1         3  Ходовая                               Стойки стабилизатора
# 2         3  Ходовая                               Стойки стабилизатора
# 3         3  Ходовая                               Стойки стабилизатора
# 4         3  Ходовая                               Стойки стабилизатора
# ...     ...      ...                                                ...
# 29922     3  Ходовая  Машина сама тормозит  после того как убираю но...
# 29923     3  Ходовая  Машина сама тормозит  после того как убираю но...
# 29924     3  Ходовая  Машина сама тормозит  после того как убираю но...
# 29925     3  Ходовая  Машина сама тормозит  после того как убираю но...
# 29926     3  Ходовая  Машина сама тормозит  после того как убираю но...
#
#               Date          Author  \
# 0      20 авг 2014          kudzho
# ...

# %%
## Удаляем колеса из каталога про ходовую часть
mess[-f].to_csv(path_or_buf='./' + f_name, index=False, quotechar="'", escapechar='`')
